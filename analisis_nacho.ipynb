# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('df_final.csv')
df = df.drop('Unnamed: 0',axis=1)
df
# Out:
#             ehr  birth_date diagnosis_date death_date   er  her2  ki67   pr  \
# 0      10011773  05-07-1959     02-04-2015        NaN  0.0   0.0  19.0  1.0
# 1      10020495  02-10-1953     04-12-2017        NaN  1.0   0.0   9.0  0.0
# 2      10030299  16-08-1966     27-06-2019        NaN  1.0   0.0  18.0  1.0
# 3      10030824  03-03-1953     07-09-2018        NaN  1.0   0.0  18.0  1.0
# 4      10041592  06-07-1959     19-11-2018        NaN  0.0   0.0  65.0  0.0
# ...         ...         ...            ...        ...  ...   ...   ...  ...
# 11162  99343880  23-08-1944     28-05-2018        NaN  1.0   0.0  68.0  1.0
# 11163  99443402  17-06-1959     21-01-2018        NaN  1.0   0.0  22.0  0.0
# 11164  99656792  26-03-1976     23-07-2017        NaN  1.0   1.0  49.0  0.0
# 11165  99690760  21-07-1961     28-10-2013        NaN  1.0   0.0  20.0  1.0
# 11166  99807703  06-08-1948     08-07-2017        NaN  1.0   0.0  11.0  1.0
#
#        pregnancy  birth  ...  m_category  t_category_after_neoadj  \
# 0            0.0    0.0  ...         0.0          SIN TRATAMIENTO
# 1            0.0    0.0  ...         0.0          SIN TRATAMIENTO
# 2            3.0    3.0  ...         0.0          SIN TRATAMIENTO
# 3            0.0    0.0  ...         0.0                        2
# 4            0.0    0.0  ...         0.0                        4
# ...          ...    ...  ...         ...                      ...
# 11162        2.0    2.0  ...         1.0          SIN TRATAMIENTO
# 11163        0.0    0.0  ...         1.0          SIN TRATAMIENTO
# 11164        0.0    0.0  ...         0.0                        4
# 11165        1.0    1.0  ...         0.0          SIN TRATAMIENTO
# 11166        1.0    1.0  ...         0.0                        4
#
#        n_category_after_neoadj  m_category_after_neoadj  stage_diagnosis  \
# 0              SIN TRATAMIENTO          SIN TRATAMIENTO                0
# 1              SIN TRATAMIENTO          SIN TRATAMIENTO               IA
# 2              SIN TRATAMIENTO          SIN TRATAMIENTO               IA
# 3                          2.0                      0.0             IIIA
# 4                          0.0                      0.0               IB
# ...                        ...                      ...              ...
# 11162          SIN TRATAMIENTO          SIN TRATAMIENTO               IA
# 11163          SIN TRATAMIENTO          SIN TRATAMIENTO              IIB
# 11164                      0.0                        0               IA
# 11165          SIN TRATAMIENTO          SIN TRATAMIENTO               IA
# 11166                      0.0                        0             IIIA
#
#        stage_after_neo  grade  ductal lobular neoadjuvant
# 0      SIN TRATAMIENTO    1.0     0.0     0.0         0.0
# 1      SIN TRATAMIENTO    2.0     1.0     0.0         0.0
# 2      SIN TRATAMIENTO    1.0     1.0     0.0         0.0
# 3                 IIIA    3.0     0.0     1.0         1.0
# 4                   IA    2.0     1.0     0.0         1.0
# ...                ...    ...     ...     ...         ...
# 11162  SIN TRATAMIENTO    2.0     0.0     0.0         0.0
# 11163  SIN TRATAMIENTO    3.0     0.0     1.0         0.0
# 11164  SIN TRATAMIENTO    1.0     0.0     0.0         1.0
# 11165  SIN TRATAMIENTO    1.0     1.0     0.0         0.0
# 11166  SIN TRATAMIENTO    2.0     0.0     1.0         1.0
#
# [11167 rows x 27 columns]

# %%
correlaciones = df.corr(method='pearson')
correlaciones.style.background_gradient(cmap='coolwarm',axis=None).set_precision(3)
# Out:
# C:\Users\34699\AppData\Local\Temp\ipykernel_2808\732683472.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones = df.corr(method='pearson')
# C:\Users\34699\AppData\Local\Temp\ipykernel_2808\732683472.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   correlaciones.style.background_gradient(cmap='coolwarm',axis=None).set_precision(3)
# <style type="text/css">
# #T_40085_row0_col0, #T_40085_row1_col1, #T_40085_row2_col2, #T_40085_row3_col3, #T_40085_row4_col4, #T_40085_row5_col5, #T_40085_row6_col6, #T_40085_row7_col7, #T_40085_row8_col8, #T_40085_row9_col9, #T_40085_row10_col10, #T_40085_row11_col11, #T_40085_row12_col12, #T_40085_row13_col13, #T_40085_row14_col14, #T_40085_row15_col15, #T_40085_row16_col16, #T_40085_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_40085_row0_col1, #T_40085_row0_col6, #T_40085_row1_col0, #T_40085_row2_col9, #T_40085_row2_col11, #T_40085_row3_col7, #T_40085_row3_col10, #T_40085_row4_col10, #T_40085_row4_col16, #T_40085_row5_col9, #T_40085_row5_col10, #T_40085_row5_col13, #T_40085_row5_col14, #T_40085_row6_col0, #T_40085_row6_col9, #T_40085_row6_col17, #T_40085_row7_col3, #T_40085_row8_col10, #T_40085_row8_col11, #T_40085_row8_col12, #T_40085_row8_col15, #T_40085_row9_col2, #T_40085_row9_col5, #T_40085_row9_col6, #T_40085_row9_col15, #T_40085_row10_col3, #T_40085_row10_col4, #T_40085_row10_col5, #T_40085_row10_col8, #T_40085_row11_col2, #T_40085_row11_col8, #T_40085_row12_col8, #T_40085_row12_col14, #T_40085_row13_col5, #T_40085_row13_col16, #T_40085_row14_col5, #T_40085_row14_col12, #T_40085_row15_col8, #T_40085_row15_col9, #T_40085_row16_col4, #T_40085_row16_col13, #T_40085_row17_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_40085_row0_col2, #T_40085_row0_col10, #T_40085_row0_col14, #T_40085_row2_col0, #T_40085_row2_col7, #T_40085_row3_col8, #T_40085_row5_col16, #T_40085_row7_col2, #T_40085_row8_col3, #T_40085_row9_col13, #T_40085_row10_col0, #T_40085_row12_col13, #T_40085_row13_col9, #T_40085_row13_col12, #T_40085_row14_col0, #T_40085_row16_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_40085_row0_col3, #T_40085_row1_col5, #T_40085_row1_col6, #T_40085_row1_col9, #T_40085_row3_col0, #T_40085_row4_col8, #T_40085_row4_col13, #T_40085_row5_col1, #T_40085_row6_col1, #T_40085_row8_col4, #T_40085_row9_col1, #T_40085_row10_col12, #T_40085_row12_col10, #T_40085_row13_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_40085_row0_col4, #T_40085_row0_col12, #T_40085_row0_col15, #T_40085_row0_col16, #T_40085_row0_col17, #T_40085_row1_col10, #T_40085_row1_col15, #T_40085_row3_col12, #T_40085_row4_col0, #T_40085_row4_col11, #T_40085_row6_col10, #T_40085_row6_col11, #T_40085_row7_col11, #T_40085_row7_col13, #T_40085_row10_col1, #T_40085_row10_col6, #T_40085_row10_col13, #T_40085_row10_col17, #T_40085_row11_col4, #T_40085_row11_col6, #T_40085_row11_col7, #T_40085_row11_col15, #T_40085_row12_col0, #T_40085_row12_col3, #T_40085_row13_col7, #T_40085_row13_col10, #T_40085_row14_col16, #T_40085_row15_col0, #T_40085_row15_col1, #T_40085_row15_col11, #T_40085_row16_col0, #T_40085_row16_col14, #T_40085_row17_col0, #T_40085_row17_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_40085_row0_col5, #T_40085_row0_col7, #T_40085_row0_col8, #T_40085_row0_col11, #T_40085_row1_col12, #T_40085_row1_col13, #T_40085_row2_col5, #T_40085_row2_col8, #T_40085_row2_col15, #T_40085_row2_col16, #T_40085_row3_col6, #T_40085_row3_col11, #T_40085_row3_col13, #T_40085_row3_col16, #T_40085_row4_col5, #T_40085_row4_col9, #T_40085_row5_col0, #T_40085_row5_col2, #T_40085_row5_col4, #T_40085_row6_col3, #T_40085_row6_col13, #T_40085_row7_col0, #T_40085_row7_col10, #T_40085_row7_col14, #T_40085_row7_col15, #T_40085_row8_col0, #T_40085_row8_col2, #T_40085_row8_col13, #T_40085_row9_col4, #T_40085_row9_col14, #T_40085_row9_col16, #T_40085_row9_col17, #T_40085_row10_col7, #T_40085_row10_col16, #T_40085_row11_col0, #T_40085_row11_col3, #T_40085_row11_col14, #T_40085_row12_col1, #T_40085_row12_col15, #T_40085_row13_col1, #T_40085_row13_col3, #T_40085_row13_col6, #T_40085_row13_col8, #T_40085_row13_col14, #T_40085_row14_col7, #T_40085_row14_col9, #T_40085_row14_col11, #T_40085_row14_col13, #T_40085_row15_col2, #T_40085_row15_col7, #T_40085_row15_col12, #T_40085_row15_col17, #T_40085_row16_col2, #T_40085_row16_col3, #T_40085_row16_col9, #T_40085_row16_col10, #T_40085_row16_col17, #T_40085_row17_col9, #T_40085_row17_col15, #T_40085_row17_col16 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_40085_row0_col9, #T_40085_row3_col5, #T_40085_row4_col7, #T_40085_row4_col12, #T_40085_row4_col15, #T_40085_row5_col3, #T_40085_row5_col17, #T_40085_row7_col4, #T_40085_row8_col17, #T_40085_row9_col0, #T_40085_row10_col15, #T_40085_row12_col4, #T_40085_row15_col4, #T_40085_row15_col10, #T_40085_row17_col5, #T_40085_row17_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_40085_row0_col13, #T_40085_row1_col8, #T_40085_row2_col6, #T_40085_row2_col13, #T_40085_row3_col15, #T_40085_row5_col11, #T_40085_row6_col2, #T_40085_row6_col14, #T_40085_row7_col9, #T_40085_row8_col1, #T_40085_row9_col7, #T_40085_row9_col10, #T_40085_row10_col9, #T_40085_row11_col5, #T_40085_row12_col16, #T_40085_row13_col0, #T_40085_row13_col2, #T_40085_row14_col6, #T_40085_row15_col3, #T_40085_row16_col12 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_40085_row1_col2, #T_40085_row2_col1, #T_40085_row4_col14, #T_40085_row4_col17, #T_40085_row13_col17, #T_40085_row14_col4, #T_40085_row17_col4, #T_40085_row17_col13 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_40085_row1_col3, #T_40085_row3_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_40085_row1_col4, #T_40085_row4_col1, #T_40085_row11_col12, #T_40085_row12_col11, #T_40085_row12_col17, #T_40085_row17_col12 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_40085_row1_col7, #T_40085_row1_col11, #T_40085_row1_col16, #T_40085_row2_col10, #T_40085_row2_col12, #T_40085_row3_col9, #T_40085_row4_col6, #T_40085_row5_col12, #T_40085_row5_col15, #T_40085_row6_col4, #T_40085_row6_col12, #T_40085_row6_col15, #T_40085_row6_col16, #T_40085_row7_col1, #T_40085_row7_col12, #T_40085_row7_col16, #T_40085_row7_col17, #T_40085_row8_col9, #T_40085_row8_col14, #T_40085_row8_col16, #T_40085_row9_col3, #T_40085_row9_col8, #T_40085_row9_col11, #T_40085_row9_col12, #T_40085_row10_col2, #T_40085_row10_col11, #T_40085_row10_col14, #T_40085_row11_col1, #T_40085_row11_col9, #T_40085_row11_col10, #T_40085_row11_col16, #T_40085_row12_col2, #T_40085_row12_col5, #T_40085_row12_col6, #T_40085_row12_col7, #T_40085_row12_col9, #T_40085_row13_col15, #T_40085_row14_col8, #T_40085_row14_col10, #T_40085_row14_col15, #T_40085_row14_col17, #T_40085_row15_col5, #T_40085_row15_col6, #T_40085_row15_col13, #T_40085_row15_col14, #T_40085_row16_col1, #T_40085_row16_col6, #T_40085_row16_col7, #T_40085_row16_col8, #T_40085_row16_col11, #T_40085_row17_col7, #T_40085_row17_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_40085_row1_col14, #T_40085_row14_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_40085_row1_col17, #T_40085_row17_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_40085_row2_col3, #T_40085_row3_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_40085_row2_col4, #T_40085_row4_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_40085_row2_col14, #T_40085_row14_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_40085_row2_col17, #T_40085_row17_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_40085_row3_col4, #T_40085_row4_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_40085_row3_col14, #T_40085_row14_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_40085_row3_col17, #T_40085_row17_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_40085_row5_col6, #T_40085_row6_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_40085_row5_col7, #T_40085_row7_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_40085_row5_col8, #T_40085_row8_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_40085_row6_col7, #T_40085_row7_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_40085_row6_col8, #T_40085_row8_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_40085_row7_col8, #T_40085_row8_col7 {
#   background-color: #6282ea;
#   color: #

# %% [markdown]
# Observamos que las correlaciones no nos aportan información, ya que son muy bajas para todos los valores no esperados. Para las variables en las que sí esperábamos correlación alta, como 'birth' y 'pregnancy', o 'ductal' y 'lobular' sí que se da dicha correlación, pero no nos aporta iformación nueva.
